# %%
import pandas as pd

df = pd.read_csv("raw_rfm_sales_transactions_30000.csv") 
df.head()
# Out:
#   Transaction ID        Date Product ID                   Product Name  \
# 0   Customer-001      Yangon        NaN                            NaN
# 1        T000001  01.01.2025   PROD-008    Executive Ballpoint Pen Box
# 2        T000002  01.01.2025   PROD-002   Wireless Mechanical Keyboard
# 3        T000003  01.01.2025   PROD-004        Standing Desk Converter
# 4        T000004  01.01.2025   PROD-006  A4 Printer Paper (500 Sheets)
#
#   Product Category  Quantity      PPU     Amount
# 0              NaN       NaN      NaN        NaN
# 1  Office Supplies       8.0   70,000    560,000
# 2      Electronics      10.0  380,000  3,800,000
# 3        Furniture       6.0  500,000  3,000,000
# 4  Office Supplies       3.0   25,500     76,500

# %%
df.tail()
# Out:
#       Transaction ID        Date Product ID                   Product Name  \
# 30095        T029544  24.06.2025   PROD-007          USB-C Docking Station
# 30096        T029545  24.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 30097        T029612  25.06.2025   PROD-008    Executive Ballpoint Pen Box
# 30098        T029681  26.06.2025   PROD-003             27-inch 4K Monitor
# 30099        T029829  28.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
#
#       Product Category  Quantity        PPU     Amount
# 30095      Electronics       4.0    340,000  1,360,000
# 30096  Office Supplies       2.0     25,500     51,000
# 30097  Office Supplies      10.0     70,000    700,000
# 30098      Electronics       6.0  1,200,000  7,200,000
# 30099  Office Supplies       6.0     25,500    153,000

# %%
df.shape
# Out:
# (30100, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30100 entries, 0 to 30099
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    30100 non-null  object
#  1   Date              30100 non-null  object
#  2   Product ID        30000 non-null  object
#  3   Product Name      30000 non-null  object
#  4   Product Category  30000 non-null  object
#  5   Quantity          30000 non-null  float64
#  6   PPU               30000 non-null  object
#  7   Amount            30000 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#            Quantity
# count  30000.000000
# mean       5.490067
# std        2.880008
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product ID', 'Product Name',
#        'Product Category', 'Quantity', 'PPU', 'Amount'],
#       dtype='object')

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product ID          0
# Product Name        0
# Product Category    0
# Quantity            0
# PPU                 0
# Amount              0
# dtype: int64

# %%
df.dropna()
# Out:
#       Transaction ID        Date Product ID                   Product Name  \
# 1            T000001  01.01.2025   PROD-008    Executive Ballpoint Pen Box
# 2            T000002  01.01.2025   PROD-002   Wireless Mechanical Keyboard
# 3            T000003  01.01.2025   PROD-004        Standing Desk Converter
# 4            T000004  01.01.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 5            T000308  02.01.2025   PROD-002   Wireless Mechanical Keyboard
# ...              ...         ...        ...                            ...
# 30095        T029544  24.06.2025   PROD-007          USB-C Docking Station
# 30096        T029545  24.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 30097        T029612  25.06.2025   PROD-008    Executive Ballpoint Pen Box
# 30098        T029681  26.06.2025   PROD-003             27-inch 4K Monitor
# 30099        T029829  28.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
#
#       Product Category  Quantity        PPU     Amount
# ...

# %%
df.dropna(subset=["PPU"])
# Out:
#       Transaction ID        Date Product ID                   Product Name  \
# 1            T000001  01.01.2025   PROD-008    Executive Ballpoint Pen Box
# 2            T000002  01.01.2025   PROD-002   Wireless Mechanical Keyboard
# 3            T000003  01.01.2025   PROD-004        Standing Desk Converter
# 4            T000004  01.01.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 5            T000308  02.01.2025   PROD-002   Wireless Mechanical Keyboard
# ...              ...         ...        ...                            ...
# 30095        T029544  24.06.2025   PROD-007          USB-C Docking Station
# 30096        T029545  24.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 30097        T029612  25.06.2025   PROD-008    Executive Ballpoint Pen Box
# 30098        T029681  26.06.2025   PROD-003             27-inch 4K Monitor
# 30099        T029829  28.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
#
#       Product Category  Quantity        PPU     Amount
# ...

# %%
df.fillna(0)
# Out:
#       Transaction ID        Date Product ID                   Product Name  \
# 1            T000001  01.01.2025   PROD-008    Executive Ballpoint Pen Box
# 2            T000002  01.01.2025   PROD-002   Wireless Mechanical Keyboard
# 3            T000003  01.01.2025   PROD-004        Standing Desk Converter
# 4            T000004  01.01.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 5            T000308  02.01.2025   PROD-002   Wireless Mechanical Keyboard
# ...              ...         ...        ...                            ...
# 30095        T029544  24.06.2025   PROD-007          USB-C Docking Station
# 30096        T029545  24.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 30097        T029612  25.06.2025   PROD-008    Executive Ballpoint Pen Box
# 30098        T029681  26.06.2025   PROD-003             27-inch 4K Monitor
# 30099        T029829  28.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
#
#       Product Category  Quantity        PPU     Amount
# ...

# %%
df["PPU"].ffill()
# Out:
# 1           70,000
# 2          380,000
# 3          500,000
# 4           25,500
# 5          380,000
#            ...
# 30095      340,000
# 30096       25,500
# 30097       70,000
# 30098    1,200,000
# 30099       25,500
# Name: PPU, Length: 30000, dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#       Transaction ID        Date Product ID                   Product Name  \
# 1            T000001  01.01.2025   PROD-008    Executive Ballpoint Pen Box
# 2            T000002  01.01.2025   PROD-002   Wireless Mechanical Keyboard
# 3            T000003  01.01.2025   PROD-004        Standing Desk Converter
# 4            T000004  01.01.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 5            T000308  02.01.2025   PROD-002   Wireless Mechanical Keyboard
# ...              ...         ...        ...                            ...
# 30095        T029544  24.06.2025   PROD-007          USB-C Docking Station
# 30096        T029545  24.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 30097        T029612  25.06.2025   PROD-008    Executive Ballpoint Pen Box
# 30098        T029681  26.06.2025   PROD-003             27-inch 4K Monitor
# 30099        T029829  28.06.2025   PROD-006  A4 Printer Paper (500 Sheets)
#
#       Product Category  Quantity        PPU     Amount
# ...

# %%
df.drop_duplicates(subset=["PPU"])
# Out:
#    Transaction ID        Date Product ID                   Product Name  \
# 1         T000001  01.01.2025   PROD-008    Executive Ballpoint Pen Box
# 2         T000002  01.01.2025   PROD-002   Wireless Mechanical Keyboard
# 3         T000003  01.01.2025   PROD-004        Standing Desk Converter
# 4         T000004  01.01.2025   PROD-006  A4 Printer Paper (500 Sheets)
# 8         T000912  04.01.2025   PROD-001           Ergonomic Mesh Chair
# 9         T001206  05.01.2025   PROD-009         Adjustable Monitor Arm
# 14        T001857  07.01.2025   PROD-010                Webcam 1080p HD
# 15        T002730  10.01.2025   PROD-005    Noise-Cancelling Headphones
# 19        T003341  12.01.2025   PROD-003             27-inch 4K Monitor
# 31        T005485  19.01.2025   PROD-007          USB-C Docking Station
#
#    Product Category  Quantity        PPU      Amount
# 1   Office Supplies       8.0     70,000     560,000
# 2       Electronics      10.0    380,000   3,800,000
# ...

# %%
import matplotlib.pyplot as plt
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# %%
df.groupby('Date')['Amount'].sum().sort_values().plot(kind='line',marker='o',figsize=(12,4))
plt.show()

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product ID', 'Product Name',
#        'Product Category', 'Quantity', 'PPU', 'Amount'],
#       dtype='object')

# %%
# 1. Which product category has highest sales?
df.groupby('Product Category')['Amount'].sum().sort_values(ascending=False)
# Out:
# Product Category
# Electronics        0.0
# Furniture          0.0
# Office Supplies    0.0
# Name: Amount, dtype: float64

# %%
df.groupby('Date')['Amount'].sum().sort_values().plot(kind='barh')
plt.show()
